# %% [markdown]
# # Matplotlib came from matlab and that's why it is called mat plot lib.

# %%
# import
import matplotlib.pyplot as plt

import numpy as np

# %%
plt.plot([1,6,3,4,5])
plt.ylabel('this is y')
plt.xlabel('this is x')
plt.title('a sample plot')
plt.show()

# %%
plt.plot(np.array([1, 3, 6, 2, 9]))
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16])
plt.xlabel('this is x')
plt.ylabel('this is y')
plt.title('squares of numbers')
plt.grid()
plt.show()

# %%
plt.plot([1,2,3,4], 'ro') # red oh
plt.show()

# %%
arr = np.arange(0, 4, 0.2)

plt.plot(arr, arr ** 2, 'b--', label='^2', linewidth=5)
plt.plot(arr, arr ** 3, 'rs', label='^3')
plt.plot(arr, arr ** 4, 'g^', label='^4')

plt.grid()
plt.legend()

plt.show()

# %%
arr1 = np.array([1,2,3,4])
arr2 = arr1 ** 2
arr3 = arr1
arr4 = arr3 ** 3

lines = plt.plot(arr1, arr2, arr3, arr4)

plt.setp(lines[0], color='g', linewidth=5)

plt.show()

# %%
plt.figure(1)


plt.plot([1,2,3,4], 'r-')

plt.figure(2)
plt.subplot(221)

plt.plot([2,3,4,5],[10, 22, 44, 555], 'g--')

plt.subplot(222)
plt.plot([1,2,3,4], 'r-')
plt.subplot(224)

plt.plot([2,3,4,5],[10, 22, 44, 555], 'g--')

plt.subplot(223)
plt.plot([1,2,3,4], 'r-')

plt.show()
